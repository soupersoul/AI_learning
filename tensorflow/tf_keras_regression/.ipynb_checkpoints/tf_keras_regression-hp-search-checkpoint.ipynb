# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.1.0
# sys.version_info(major=3, minor=6, micro=9, releaselevel='final', serial=0)
# matplotlib 3.1.3
# numpy 1.18.1
# pandas 1.0.1
# sklearn 0.22.1
# tensorflow 2.1.0
# tensorflow_core.python.keras.api._v2.keras 2.2.4-tf

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()

print(housing.DESCR)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(housing.data, housing.target, random_state=7)

x_train, x_valid, y_train, y_valid = train_test_split(x_train_all, y_train_all, random_state=11)
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
# tf.keras.models.Sequential()
'''
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation='relu'))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
'''
# learning_rate: [1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2]
# W = W + grad * learning_rate
learning_rates = [1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2]
histories = []
for lr in learning_rates:
    model = keras.models.Sequential([
        keras.layers.Dense(30, activation="relu", input_shape=x_train.shape[1:]),
        keras.layers.Dense(1)
    ])
    optimizer = keras.optimizers.SGD(lr)
    model.compile(loss="mean_squared_error", optimizer=optimizer)
    callbacks = [keras.callbacks.EarlyStopping(patience=5, min_delta=1e-2)]
    history = model.fit(x_train_scaled, y_train, validation_data=(x_valid_scaled, y_valid),
                   epochs=20, callbacks=callbacks)
    histories.append(history)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 5s 421us/sample - loss: 5.1864 - val_loss: 4.3580
# Epoch 2/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 3.5586 - val_loss: 3.0504
# Epoch 3/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 2.5823 - val_loss: 2.2599
# Epoch 4/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 1.9716 - val_loss: 1.7558
# Epoch 5/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 1.5731 - val_loss: 1.4293
# Epoch 6/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 1.3116 - val_loss: 1.2186
# Epoch 7/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 1.1361 - val_loss: 1.0793
# Epoch 8/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 1.0165 - val_loss: 0.9862
# Epoch 9/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.9330 - val_loss: 0.9225
# Epoch 10/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.8740 - val_loss: 0.8785
# Epoch 11/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.8315 - val_loss: 0.8472
# Epoch 12/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.8001 - val_loss: 0.8246
# Epoch 13/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.7768 - val_loss: 0.8077
# Epoch 14/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.7589 - val_loss: 0.7947
# Epoch 15/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.7449 - val_loss: 0.7845
# Epoch 16/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.7337 - val_loss: 0.7761
# Epoch 17/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.7245 - val_loss: 0.7690
# Epoch 18/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.7169 - val_loss: 0.7629
# Epoch 19/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.7103 - val_loss: 0.7574
# Epoch 20/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.7045 - val_loss: 0.7525
# Epoch 21/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6993 - val_loss: 0.7479
# Epoch 22/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6946 - val_loss: 0.7437
# Epoch 23/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6903 - val_loss: 0.7396
# Epoch 24/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6863 - val_loss: 0.7358
# Epoch 25/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6825 - val_loss: 0.7321
# Epoch 26/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6789 - val_loss: 0.7286
# Epoch 27/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6755 - val_loss: 0.7252
# Epoch 28/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6722 - val_loss: 0.7218
# Epoch 29/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6690 - val_loss: 0.7185
# Epoch 30/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.6660 - val_loss: 0.7154
# Epoch 31/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6630 - val_loss: 0.7123
# Epoch 32/100
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.6602 - val_loss: 0.7092
# Epoch 33/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6574 - val_loss: 0.7063
# Epoch 34/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6546 - val_loss: 0.7034
# Epoch 35/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6520 - val_loss: 0.7006
# Epoch 36/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6493 - val_loss: 0.6978
# Epoch 37/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.6468 - val_loss: 0.6950
# Epoch 38/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6443 - val_loss: 0.6924
# Epoch 39/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6418 - val_loss: 0.6897
# Epoch 40/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6394 - val_loss: 0.6871
# Epoch 41/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6371 - val_loss: 0.6846
# Epoch 42/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6347 - val_loss: 0.6821
# Epoch 43/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6325 - val_loss: 0.6796
# Epoch 44/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6303 - val_loss: 0.6772
# Epoch 45/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.6281 - val_loss: 0.6748
# Epoch 46/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6259 - val_loss: 0.6725
# Epoch 47/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.6238 - val_loss: 0.6702
# Epoch 48/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6217 - val_loss: 0.6679
# Epoch 49/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6197 - val_loss: 0.6657
# Epoch 50/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6177 - val_loss: 0.6635
# Epoch 51/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6157 - val_loss: 0.6614
# Epoch 52/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6137 - val_loss: 0.6592
# Epoch 53/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.6118 - val_loss: 0.6572
# Epoch 54/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6099 - val_loss: 0.6551
# Epoch 55/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6080 - val_loss: 0.6530
# Epoch 56/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.6062 - val_loss: 0.6510
# Epoch 57/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.6044 - val_loss: 0.6491
# Epoch 58/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.6026 - val_loss: 0.6471
# Epoch 59/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6008 - val_loss: 0.6452
# Epoch 60/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5991 - val_loss: 0.6433
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 3.7633 - val_loss: 2.9710
# Epoch 2/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 2.3155 - val_loss: 2.0371
# Epoch 3/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 1.6732 - val_loss: 1.5386
# Epoch 4/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 1.2858 - val_loss: 1.2159
# Epoch 5/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 1.0347 - val_loss: 1.0079
# Epoch 6/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.8772 - val_loss: 0.8812
# Epoch 7/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.7831 - val_loss: 0.8084
# Epoch 8/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.7282 - val_loss: 0.7660
# Epoch 9/100
# 11610/11610 [==============================] - 1s 81us/sample - loss: 0.6956 - val_loss: 0.7398
# Epoch 10/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6751 - val_loss: 0.7225
# Epoch 11/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.6608 - val_loss: 0.7099
# Epoch 12/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.6499 - val_loss: 0.7001
# Epoch 13/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6409 - val_loss: 0.6915
# Epoch 14/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.6329 - val_loss: 0.6841
# Epoch 15/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.6257 - val_loss: 0.6765
# Epoch 16/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.6191 - val_loss: 0.6696
# Epoch 17/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.6128 - val_loss: 0.6628
# Epoch 18/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6068 - val_loss: 0.6571
# Epoch 19/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6012 - val_loss: 0.6510
# Epoch 20/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5957 - val_loss: 0.6450
# Epoch 21/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5906 - val_loss: 0.6393
# Epoch 22/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5856 - val_loss: 0.6339
# Epoch 23/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5808 - val_loss: 0.6286
# Epoch 24/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5762 - val_loss: 0.6236
# Epoch 25/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5717 - val_loss: 0.6185
# Epoch 26/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5674 - val_loss: 0.6138
# Epoch 27/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5633 - val_loss: 0.6091
# Epoch 28/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5592 - val_loss: 0.6043
# Epoch 29/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5553 - val_loss: 0.6000
# Epoch 30/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5515 - val_loss: 0.5956
# Epoch 31/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5478 - val_loss: 0.5912
# Epoch 32/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5442 - val_loss: 0.5874
# Epoch 33/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5407 - val_loss: 0.5833
# Epoch 34/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5373 - val_loss: 0.5792
# Epoch 35/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5339 - val_loss: 0.5752
# Epoch 36/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.5307 - val_loss: 0.5716
# Epoch 37/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5275 - val_loss: 0.5678
# Epoch 38/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5243 - val_loss: 0.5644
# Epoch 39/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.5213 - val_loss: 0.5608
# Epoch 40/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.5184 - val_loss: 0.5573
# Epoch 41/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5155 - val_loss: 0.5539
# Epoch 42/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5127 - val_loss: 0.5508
# Epoch 43/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.5100 - val_loss: 0.5477
# Epoch 44/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.5074 - val_loss: 0.5446
# Epoch 45/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5049 - val_loss: 0.5418
# Epoch 46/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5025 - val_loss: 0.5391
# Epoch 47/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5001 - val_loss: 0.5364
# Epoch 48/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4977 - val_loss: 0.5335
# Epoch 49/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4955 - val_loss: 0.5310
# Epoch 50/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4934 - val_loss: 0.5286
# Epoch 51/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4912 - val_loss: 0.5260
# Epoch 52/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4891 - val_loss: 0.5236
# Epoch 53/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4871 - val_loss: 0.5212
# Epoch 54/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4853 - val_loss: 0.5191
# Epoch 55/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.4834 - val_loss: 0.5169
# Epoch 56/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4816 - val_loss: 0.5149
# Epoch 57/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4799 - val_loss: 0.5129
# Epoch 58/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.4783 - val_loss: 0.5110
# Epoch 59/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4767 - val_loss: 0.5090
# Epoch 60/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4752 - val_loss: 0.5073
# Epoch 61/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4737 - val_loss: 0.5055
# Epoch 62/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4723 - val_loss: 0.5038
# Epoch 63/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4709 - val_loss: 0.5021
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 2.2666 - val_loss: 0.9013
# Epoch 2/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.7256 - val_loss: 0.7138
# Epoch 3/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6402 - val_loss: 0.6832
# Epoch 4/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.6147 - val_loss: 0.6608
# Epoch 5/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5940 - val_loss: 0.6368
# Epoch 6/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5759 - val_loss: 0.6174
# Epoch 7/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5606 - val_loss: 0.5998
# Epoch 8/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5467 - val_loss: 0.5848
# Epoch 9/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.5349 - val_loss: 0.5708
# Epoch 10/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5250 - val_loss: 0.5623
# Epoch 11/100
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.5169 - val_loss: 0.5524
# Epoch 12/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5090 - val_loss: 0.5431
# Epoch 13/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5022 - val_loss: 0.5374
# Epoch 14/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4974 - val_loss: 0.5296
# Epoch 15/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.4919 - val_loss: 0.5231
# Epoch 16/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4874 - val_loss: 0.5179
# Epoch 17/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4830 - val_loss: 0.5168
# Epoch 18/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4799 - val_loss: 0.5098
# Epoch 19/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4767 - val_loss: 0.5076
# Epoch 20/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4735 - val_loss: 0.5045
# Epoch 21/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4712 - val_loss: 0.4996
# Epoch 22/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.4678 - val_loss: 0.4972
# Epoch 23/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4657 - val_loss: 0.4940
# Epoch 24/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4628 - val_loss: 0.4934
# Epoch 25/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4603 - val_loss: 0.4870
# Epoch 26/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4587 - val_loss: 0.4841
# Epoch 27/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4568 - val_loss: 0.4843
# Epoch 28/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4540 - val_loss: 0.4824
# Epoch 29/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4519 - val_loss: 0.4779
# Epoch 30/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.4504 - val_loss: 0.4764
# Epoch 31/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4483 - val_loss: 0.4744
# Epoch 32/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4464 - val_loss: 0.4723
# Epoch 33/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4447 - val_loss: 0.4774
# Epoch 34/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4430 - val_loss: 0.4709
# Epoch 35/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4411 - val_loss: 0.4673
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 1.2437 - val_loss: 0.7371
# Epoch 2/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.6599 - val_loss: 0.6407
# Epoch 3/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5626 - val_loss: 0.5950
# Epoch 4/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5253 - val_loss: 0.5500
# Epoch 5/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4970 - val_loss: 0.5170
# Epoch 6/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4779 - val_loss: 0.4979
# Epoch 7/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4636 - val_loss: 0.4820
# Epoch 8/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4508 - val_loss: 0.4723
# Epoch 9/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4420 - val_loss: 0.4621
# Epoch 10/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4336 - val_loss: 0.4632
# Epoch 11/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.4302 - val_loss: 0.4471
# Epoch 12/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.4256 - val_loss: 0.4419
# Epoch 13/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4215 - val_loss: 0.4363
# Epoch 14/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.4152 - val_loss: 0.4321
# Epoch 15/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4118 - val_loss: 0.4326
# Epoch 16/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4068 - val_loss: 0.4219
# Epoch 17/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4029 - val_loss: 0.4182
# Epoch 18/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4004 - val_loss: 0.4213
# Epoch 19/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.3959 - val_loss: 0.4150
# Epoch 20/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3936 - val_loss: 0.4090
# Epoch 21/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3922 - val_loss: 0.4089
# Epoch 22/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3897 - val_loss: 0.4076
# Epoch 23/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3883 - val_loss: 0.4061
# Epoch 24/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3864 - val_loss: 0.4027
# Epoch 25/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3846 - val_loss: 0.4037
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 1.2956 - val_loss: 0.7124
# Epoch 2/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5363 - val_loss: 0.4847
# Epoch 3/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.4414 - val_loss: 0.4538
# Epoch 4/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4157 - val_loss: 0.4254
# Epoch 5/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4030 - val_loss: 0.4192
# Epoch 6/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3952 - val_loss: 0.4060
# Epoch 7/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3890 - val_loss: 0.4044
# Epoch 8/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3844 - val_loss: 0.3961
# Epoch 9/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3813 - val_loss: 0.3927
# Epoch 10/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3767 - val_loss: 0.3873
# Epoch 11/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3743 - val_loss: 0.3839
# Epoch 12/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3705 - val_loss: 0.3846
# Epoch 13/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3691 - val_loss: 0.3845
# Epoch 14/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3684 - val_loss: 0.3912
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 81us/sample - loss: 0.7336 - val_loss: 0.9799
# Epoch 2/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 64.3035 - val_loss: 1.2020
# Epoch 3/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: nan - val_loss: nan
# Epoch 4/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: nan - val_loss: nan
# Epoch 5/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: nan - val_loss: nan
# Epoch 6/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: nan - val_loss: nan

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=[8, 5])
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
for lr, history in zip(learning_rates, histories):
    print("Learning rate: ", lr)
    plot_learning_curves(history)
